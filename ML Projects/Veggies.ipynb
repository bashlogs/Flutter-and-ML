# %% [markdown]
# ## End-to-End Classifiation of Veggies 🥦🥬

# %%
things_to_learn={1:'Check your tensorflow version',
                 2:'Import the required libraries',
                 3:'Walk through the data',
                 4:'Peform data augmentation',
                 5:"Check the number of classes",
                 6:'Build a CNN model(Wohhh here we are)',
                 7:'Compile your model',
                 8:'Fit the model',
                 9:'Check how well your model is(Putting it all together)',
                 10:'Check predictions of your model',
                 11:'Save your model'}
things_to_learn
# Out:
# {1: 'Check your tensorflow version',
#  2: 'Import the required libraries',
#  3: 'Walk through the data',
#  4: 'Peform data augmentation',
#  5: 'Check the number of classes',
#  6: 'Build a CNN model(Wohhh here we are)',
#  7: 'Compile your model',
#  8: 'Fit the model',
#  9: 'Check how well your model is(Putting it all together)',
#  10: 'Check predictions of your model',
#  11: 'Save your model'}

# %% [markdown]
# ### 1. Checking the TensorFlow Version

# %%
import tensorflow
print(tensorflow.__version__)
# Out:
# 2.11.0

# %% [markdown]
# ### 2. Importing the required libraries

# %%
# Import libraries
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from keras.layers import *
from keras.models import *
from keras.preprocessing import image
from keras.preprocessing.image import ImageDataGenerator
import os, shutil
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Downloading The Vegetable Dataset Zip

# %%
#!pip install gdown
# !gdown https://drive.google.com/uc?id=13IicsDZW_3RPmVD8luOOSZcRX_YFvKna
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=13IicsDZW_3RPmVD8luOOSZcRX_YFvKna
# To: /content/Vegetable Images.zip
# 100% 569M/569M [00:02<00:00, 274MB/s]

# %% [markdown]
# ###  If your drives folder after downloading  says copy of copy.... then just rename it to  **Vegetable Images**

# %% [markdown]
# ### UnZipping The Data

# %%
# !unzip "/content/Vegetable Images.zip"
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: Vegetable Images/validation/Pumpkin/1255.jpg
#   inflating: __MACOSX/Vegetable Images/validation/Pumpkin/._1255.jpg
#   inflating: Vegetable Images/validation/Pumpkin/1269.jpg
#   inflating: __MACOSX/Vegetable Images/validation/Pumpkin/._1269.jpg
#   inflating: Vegetable Images/validation/Pumpkin/1282.jpg
#   inflating: __MACOSX/Vegetable Images/validation/Pumpkin/._1282.jpg
#   inflating: Vegetable Images/validation/Pumpkin/1296.jpg
#   inflating: __MACOSX/Vegetable Images/validation/Pumpkin/._1296.jpg
#   inflating: Vegetable Images/validation/Pumpkin/1297.jpg
#   inflating: __MACOSX/Vegetable Images/validation/Pumpkin/._1297.jpg
#   inflating: Vegetable Images/validation/Pumpkin/1283.jpg
#   inflating: __MACOSX/Vegetable Images/validation/Pumpkin/._1283.jpg
#   inflating: Vegetable Images/validation/Pumpkin/1268.jpg
#   inflating: __MACOSX/Vegetable Images/validation/Pumpkin/._1268.jpg
#   inflating: Vegetable Images/validation/Pumpkin/1254.jpg
#   inflating: __MACOSX/Vegetable Images/validation/Pumpkin/._1254.jpg
#   inflating: Vegetable Images/validation/Pumpkin/1240.jpg
#   inflating: __MACOSX/Vegetable Images/validation/Pumpkin/._1240.jpg
#   inflating: Vegetable Images/validation/Pumpkin/1308.jpg
#   inflating: __MACOSX/Vegetable Images/validation/Pumpkin/._1308.jpg
#   inflating: Vegetable Images/validation/Pumpkin/1320.jpg
#   inflating: __MACOSX/Vegetable Images/validation/Pumpkin/._1320.jpg
#   inflating: Vegetable Images/validation/Pumpkin/1334.jpg
#   inflating: __MACOSX/Vegetable Images/validation/Pumpkin/._1334.jpg
#   inflating: Vegetable Images/validation/Pumpkin/1339.jpg
#   inflating: __MACOSX/Vegetable Images/validation/Pumpkin/._1339.jpg
#   inflating: Vegetable Images/validation/Pumpkin/1311.jpg
#   inflating: __MACOSX/Vegetable Images/validation/Pumpkin/._1311.jpg
#   inflating: Vegetable Images/validation/Pumpkin/1305.jpg
#   inflating: __MACOSX/Vegetable Images/validation/Pumpkin/._1305.jpg
#   inflating: Vegetable Images/validation/Pumpkin/1259.jpg
#   inflating: __MACOSX/Vegetable Images/validation/Pumpkin/._1259.jpg
#   inflating: Vegetable Images/validation/Pumpkin/1265.jpg
#   inflating: __MACOSX/Vegetable Images/validation/Pumpkin/._1265.jpg
#   inflating: Vegetable Images/validation/Pumpkin/1271.jpg
#   inflating: __MACOSX/Vegetable Images/validation/Pumpkin/._1271.jpg
#   inflating: Vegetable Images/validation/Pumpkin/1270.jpg
#   inflating: __MACOSX/Vegetable Images/validation/Pumpkin/._1270.jpg
#   inflating: Vegetable Images/validation/Pumpkin/1264.jpg
#   inflating: __MACOSX/Vegetable Images/validation/Pumpkin/._1264.jpg
#   inflating: Vegetable Images/validation/Pumpkin/1258.jpg
#   inflating: __MACOSX/Vegetable Images/validation/Pumpkin/._1258.jpg
#   inflating: Vegetable Images/validation/Pumpkin/1304.jpg
#   inflating: __MACOSX/Vegetable Images/validation/Pumpkin/._1304.jpg
#   inflating: Vegetable Images/validation/Pumpkin/1310.jpg
#   inflating: __MACOSX/Vegetable Images/validation/Pumpkin/._1310.jpg
#   inflating: Vegetable Images/validation/Pumpkin/1338.jpg
#   inflating: __MACOSX/Vegetable Images/validation/Pumpkin/._1338.jpg
#   inflating: Vegetable Images/validation/Pumpkin/1306.jpg
#   inflating: __MACOSX/Vegetable Images/validation/Pumpkin/._1306.jpg
#   inflating: Vegetable Images/validation/Pumpkin/1312.jpg
#   inflating: __MACOSX/Vegetable Images/validation/Pumpkin/._1312.jpg
#   inflating: Vegetable Images/validation/Pumpkin/1272.jpg
#   inflating: __MACOSX/Vegetable Images/validation/Pumpkin/._1272.jpg
#   inflating: Vegetable Images/validation/Pumpkin/1266.jpg
#   inflating: __MACOSX/Vegetable Images/validation/Pumpkin/._1266.jpg
#   inflating: Vegetable Images/validation/Pumpkin/1299.jpg
#   inflating: __MACOSX/Vegetable Images/validation/Pumpkin/._1299.jpg
#   inflating: Vegetable Images/validation/Pumpkin/1298.jpg
#   inflating: __MACOSX/Vegetable Images/validation/Pumpkin/._1298.jpg
#   inflating: Vegetable Images/validation/Pumpkin/1267.jpg
#   inflating: __MACOSX/Vegetable Images/validation/Pumpkin/._1267.jpg
#   inflating: Vegetable Images/validation/Pumpkin/1273.jpg
#   inflating: __MACOSX/Vegetable Images/validation/Pumpkin/._1273.jpg
#   inflating: Vegetable Images/validation/Pumpkin/1313.jpg
#   inflating: __MACOSX/Vegetable Images/validation/Pumpkin/._1313.jpg
#   inflating: Vegetable Images/validation/Pumpkin/1307.jpg
#   inflating: __MACOSX/Vegetable Images/validation/Pumpkin/._1307.jpg
#   inflating: Vegetable Images/validation/Pumpkin/1303.jpg
#   inflating: __MACOSX/Vegetable Images/validation/Pumpkin/._1303.jpg
#   inflating: Vegetable Images/validation/Pumpkin/1317.jpg
#   inflating: __MACOSX/Vegetable Images/validation/Pumpkin/._1317.jpg
#   inflating: Vegetable Images/validation/Pumpkin/1277.jpg
#   inflating: __MACOSX/Vegetable Images/validation/Pumpkin/._1277.jpg
#   inflating: Vegetable Images/validation/Pumpkin/1263.jpg
#   inflating: __MACOSX/Vegetable Images/validation/Pumpkin/._1263.jpg
#   inflating: Vegetable Images/validation/Pumpkin/1288.jpg
#   inflating: __MACOSX/Vegetable Images/validation/Pumpkin/._1288.jpg
#   inflating: Vegetable Images/validation/Pumpkin/1289.jpg
#   inflating: __MACOSX/Vegetable Images/validation/Pumpkin/._1289.jpg
#   inflating: Vegetable Images/validation/Pumpkin/1262.jpg
#   inflating: __MACOSX/Vegetable Images/validation/Pumpkin/._1262.jpg
#   inflating: Vegetable Images/validation/Pumpkin/1276.jpg
#   inflating: __MACOSX/Vegetable Images/validation/Pumpkin/._1276.jpg
#   inflating: Vegetable Images/validation/Pumpkin/1316.jpg
#   inflating: __MACOSX/Vegetable Images/validation/Pumpkin/._1316.jpg
#   inflating: Vegetable Images/validation/Pumpkin/1302.jpg
#   inflating: __MACOSX/Vegetable Images/validation/Pumpkin/._1302.jpg
#   inflating: Vegetable Images/validation/Pumpkin/1314.jpg
#   inflating: __MACOSX/Vegetable Images/validation/Pumpkin/._1314.jpg
#   inflating: Vegetable Images/validation/Pumpkin/1300.jpg
#   inflating: __MACOSX/Vegetable Images/validation/Pumpkin/._1300.jpg
#   inflating: Vegetable Images/validation/Pumpkin/1328.jpg
#   inflating: __MACOSX/Vegetable Images/validation/Pumpkin/._1328.jpg
#   inflating: Vegetable Images/validation/Pumpkin/1260.jpg
#   inflating: __MACOSX/Vegetable Images/validation/Pumpkin/._1260.jpg
#   inflating: Vegetable Images/validation/Pumpkin/1274.jpg
#   inflating: __MACOSX/Vegetable Images/validation/Pumpkin/._1274.jpg
#   inflating: Vegetable Images/validation/Pumpkin/1248.jpg
#   inflating: __MACOSX/Vegetable Images/validation/Pumpkin/._1248.jpg
#   inflating: Vegetable Images/validation/Pumpkin/1249.jpg
#   inflating: __MACOSX/Vegetable Images/validation/Pumpkin/._1249.jpg
#   inflating: Vegetable Images/validation/Pumpkin/1275.jpg
#   inflating: __MACOSX/Vegetable Images/validation/Pumpkin/._1275.jpg
#   inflating: Vegetable Images/validation/Pumpkin/1261.jpg
#   inflating: __MACOSX/Vegetable Images/validation/Pumpkin/._1261.jpg
#   inflating: Vegetable Images/validation/Pumpkin/1329.jpg
#   inflating: __MACOSX/Vegetable Images/validation/Pumpkin/._1329.jpg
#   inflating: Vegetable Images/validation/Pumpkin/1301.jpg
#   inflating: __MACOSX/Vegetable Images/validation/Pumpkin/._1301.jpg
#   inflating: Vegetable Images/validation/Pumpkin/1315.jpg
#   inflating: __MACOSX/Vegetable Images/validation/Pumpkin/._1315.jpg
#   inflating: Vegetable Images/validation/Pumpkin/1372.jpg
#   inflating: __MACOSX/Vegetable Images/validation/Pumpkin/._1372.jpg
#   inflating: Vegetable Images/validation/Pumpkin/1400.jpg
#   inflating: __MACOSX/Vegetable Images/validation/Pumpkin/._1400.jpg
#   inflating: Vegetable Images/validation/Pumpkin/1366.jpg
#   inflating: __MACOSX/Vegetable Images/validation/Pumpkin/._1366.jpg
#   inflating: Vegetable Images/validation/Pumpkin/1399.jpg
#   inflating: __MACOSX/Vegetable Images/validation/Pumpkin/._1399.jpg
#   inflating: Vegetable Images/validation/Pumpkin/1206.jpg
#   inflating: __MACOSX/Vegetable Images/validation/Pumpkin/._1206.jpg
#   inflating: Vegetable Images/validation/Pumpkin/1212.jpg
#   inflating: __MACOSX/Vegetable Images/validation/Pumpkin/._1212.jpg
#   inflating: Vegetable Images/validation/Pumpkin/1213.jpg
#   inflating: __MACOSX/Vegetable Images/validation/Pumpkin/._1213.jpg
#   inflating: Vegetable Images/validation/Pumpkin/1207.jpg
#   inflating: __MACOSX/Vegetable Images/validation/Pumpkin/._1207.jpg
#   inflating: Vegetable Images/validation/Pumpkin/1398.jpg
#   inflating: __MACOSX/Vegetable Images/validation/Pumpkin/._1398.jpg
#   inflating: Vegetable Images/validation/Pumpkin/1367.jpg
#   inflating: __MACOSX/Vegetable Images/validation/Pumpkin/._1367.jpg
#   inflating: Vegetable Images/validation/Pumpkin/1373.jpg
#   inflating: __MACOSX/Vegetable Images/validation/Pumpkin/._1373.jpg
#   inflating: Vegetable Images/validation/Pumpkin/1359.jpg
#   inflating: __MACOSX/Vegetable Images/validation/Pumpkin/._1359.jpg
#   inflating: Vegetable Images/validation/Pumpkin/1365.jpg
#   inflating: __MACOSX/Vegetable Images/validation/Pumpkin/._1365.jpg
#   inflating: Vegetable Images/validation/Pumpkin/1371.jpg
#   inflating: __MACOSX/Vegetable Images/validation/Pumpkin/._1371.jpg
#   inflating: Vegetable Images/validation/Pumpkin/1239.jpg
#   inflating: __MACOSX/Vegetable Images/validation/Pumpkin/._1239.jpg
#   inflating: Vegetable Images/validation/Pumpkin/1211.jpg
#   inflating: __MACOSX/Vegetable Images/validation/Pumpkin/._1211.jpg
#   inflating: Vegetable Images/validation/Pumpkin/1205.jpg
#   inflating: __MACOSX/Vegetable Images/validation/Pumpkin/._1205.jpg
#   inflating: Vegetable Images/validation/Pumpkin/1204.jpg
#   inflating: __MACOSX/Vegetable Images/validation/Pumpkin/._1204.jpg
#   inflating: Vegetable Images/validation/Pumpkin/1210.jpg
#   inflating: __MACOSX/Vegetable Images/validation/Pumpkin/._1210.jpg
#   inflating: Vegetable Images/validation/Pumpkin/1238.jpg
#   inflating: __MACOSX/Vegetable Images/validation/Pumpkin/._1238.jpg
#   inflating: Vegetable Images/validation/Pumpkin/1370.jpg
#   inflating: __MACOSX/Vegetable Images/validation/Pumpkin/._1370.jpg
#   inflating: Vegetable Images/validation/Pumpkin/1364.jpg
#   inflating: __MACOSX/Vegetable Images/validation/Pumpkin/._1364.jpg
#   inflating: Vegetable Images/validation/Pumpkin/1358.jpg
#   inflating: __MACOSX/Vegetable Images/validation/Pumpkin/._1358.jpg
#   inflating: Vegetable Images/validation/Pumpkin/1360.jpg
#   inflating: __MACOSX/Vegetable Images/validation/Pumpkin/._1360.jpg
#   inflating: Vegetable Images/validation/Pumpkin/1374.jpg
#   inflating: __MACOSX/Vegetable Images/validation/Pumpkin/._1374.jpg
#   inflating: Vegetable Images/validation/Pumpkin/1348.jpg
#   inflating: __MACOSX/Vegetable Images/validation/Pumpkin/._1348.jpg
#   inflating: Vegetable Images/validation/Pumpkin/1214.jpg
#   inflating: __MACOSX/Vegetable Images/validation/Pumpkin/._1214.jpg
#   inflating: Vegetable Images/validation/Pumpkin/1228.jpg
#   inflating: __MACOSX/Vegetable Images/validation/Pumpkin/._1228.jpg
#   inflating: Vegetable Images/validation/Pumpkin/1229.jpg
#   inflating: __MACOSX/Vegetable Images/validation/Pumpkin/._1229.jpg
#   inflating: Vegetable Images/validation/Pumpkin/1201.jpg
#   inflating: __MACOSX/Vegetable Images/validation/Pumpkin/._1201.jpg
#   inflating: Vegetable Images/validation/Pumpkin/1215.jpg
#   inflating: __MACOSX/Vegetable Images/validation/Pumpkin/._1215.jpg
#   inflating: Vegetable Images/validation/Pumpkin/1349.jpg
#   inflating: __MACOSX/Vegetable Images/validation/Pumpkin/._1349.jpg
#   inflating: Vegetable Images/validation/Pumpkin/1375.jpg
#   inflating: __MACOSX/Vegetable Images/validation/Pumpkin/._1375.jpg
#   inflating: Vegetable Images/validation/Pumpkin/1361.jpg
#   inflating: __MACOSX/Vegetable Images/validation/Pumpkin/._1361.jpg
#   inflating: Vegetable Images/validation/Pumpkin/1377.jpg
#   inflating: __MACOSX/Vegetable Images/validation/Pumpkin/._1377.jpg
#   inflating: Vegetable Images/validation/Pumpkin/1363.jpg
#   inflating: __MACOSX/Vegetable Images/validation/Pumpkin/._1363.jpg
#   inflating: Vegetable Images/validation/Pumpkin/1388.jpg
#   inflating: __MACOSX/Vegetable Images/validation/Pumpkin/._1388.jpg
#   inflating: Vegetable Images/validation/Pumpkin/1203.jpg
#   inflating: __MACOSX/Vegetable Images/validation/Pumpkin/._1203.jpg
#   inflating: Vegetable Images/validation/Pumpkin/1217.jpg
#   inflating: __MACOSX/Vegetable Images/validation/Pumpkin/._
jpg
#   inflating: __MACOSX/Vegetable Images/validation/Carrot/._1362.jpg
#   inflating: Vegetable Images/validation/Carrot/1376.jpg
#   inflating: __MACOSX/Vegetable Images/validation/Carrot/._1376.jpg

# %% [markdown]
# ## 3. Walking throught the directories

# %% [markdown]
# ### Assigning The Train and Test

# %%
train_dir =  "/content/Vegetable Images/train"
test_dir = "/content/Vegetable Images/validation"

# %%
def walk_through_dir(dir_path):
  for dirpath, dirnames, filenames in os.walk(dir_path):
    print(f"There are {len(dirnames)} directories and {len(filenames)} images in '{dirpath}'.")

# %%
walk_through_dir(train_dir)
# Out:
# There are 15 directories and 0 images in '/content/Vegetable Images/train'.
# There are 0 directories and 1000 images in '/content/Vegetable Images/train/Broccoli'.
# There are 0 directories and 1000 images in '/content/Vegetable Images/train/Papaya'.
# There are 0 directories and 1000 images in '/content/Vegetable Images/train/Bitter_Gourd'.
# There are 0 directories and 1000 images in '/content/Vegetable Images/train/Cauliflower'.
# There are 0 directories and 1000 images in '/content/Vegetable Images/train/Tomato'.
# There are 0 directories and 1000 images in '/content/Vegetable Images/train/Bean'.
# There are 0 directories and 1000 images in '/content/Vegetable Images/train/Potato'.
# There are 0 directories and 1000 images in '/content/Vegetable Images/train/Brinjal'.
# There are 0 directories and 1000 images in '/content/Vegetable Images/train/Cucumber'.
# There are 0 directories and 1000 images in '/content/Vegetable Images/train/Bottle_Gourd'.
# There are 0 directories and 1000 images in '/content/Vegetable Images/train/Pumpkin'.
# There are 0 directories and 1000 images in '/content/Vegetable Images/train/Cabbage'.
# There are 0 directories and 1000 images in '/content/Vegetable Images/train/Radish'.
# There are 0 directories and 1000 images in '/content/Vegetable Images/train/Carrot'.
# There are 0 directories and 1000 images in '/content/Vegetable Images/train/Capsicum'.

# %% [markdown]
# ### 4. Perform Data Augmentation on the processed data

# %%
train_datagen_augmented = ImageDataGenerator(rescale=1/255.,
                                             rotation_range=20, # note: this is an int not a float
                                             width_shift_range=0.2,
                                             height_shift_range=0.2,
                                             zoom_range=0.2,
                                             horizontal_flip=True)

test_datagen_augmented = ImageDataGenerator(rescale=1/255.)

train_data = train_datagen_augmented.flow_from_directory(train_dir,
                                                         target_size =(224,224),
                                                         batch_size = 32,
                                                         class_mode = "categorical")
test_data = test_datagen_augmented.flow_from_directory(test_dir,
                                                         target_size =(224,224),
                                                         batch_size = 32,
                                                         class_mode = "categorical")
# Out:
# Found 15000 images belonging to 15 classes.
# Found 3000 images belonging to 15 classes.

# %% [markdown]
# ## 5. Number of Classes

# %%
class_names = list(train_data.class_indices.keys())
print(class_names)
print(len(class_names))
# Out:
# ['Bean', 'Bitter_Gourd', 'Bottle_Gourd', 'Brinjal', 'Broccoli', 'Cabbage', 'Capsicum', 'Carrot', 'Cauliflower', 'Cucumber', 'Papaya', 'Potato', 'Pumpkin', 'Radish', 'Tomato']
# 15

# %% [markdown]
# ## 6. Here comes the most interesting part for which we all have been waiting for
#
# **Build your own model**
#
# `We will building a CNN model which would be consisting of following layers`
# * Convolutional layers
# * Pooling layers
# * Flatten layers
# * Output layer

# %%
model = Sequential([
    Conv2D(10,3,activation = "relu", input_shape=(224,224,3)),
    Conv2D(10,3,activation = "relu"),
    MaxPool2D(),
    Conv2D(10,3,activation = "relu"),
    Conv2D(10,3,activation = "relu"),
    MaxPool2D(),

    Flatten(),

    Dense(15,activation = "softmax") # Multiple Categories
])

# %% [markdown]
# ### Summary Of Model

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_4 (Conv2D)           (None, 222, 222, 10)      280
#
#  conv2d_5 (Conv2D)           (None, 220, 220, 10)      910
#
#  max_pooling2d_2 (MaxPooling  (None, 110, 110, 10)     0
#  2D)
#
#  conv2d_6 (Conv2D)           (None, 108, 108, 10)      910
#
#  conv2d_7 (Conv2D)           (None, 106, 106, 10)      910
#
#  max_pooling2d_3 (MaxPooling  (None, 53, 53, 10)       0
#  2D)
#
#  flatten_1 (Flatten)         (None, 28090)             0
#
#  dense_1 (Dense)             (None, 15)                421365
#
# =================================================================
# Total params: 424,375
# Trainable params: 424,375
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## 7. Compile the model you have built

# %%
model.compile(loss="categorical_crossentropy",
              optimizer = "adam",
              metrics = 'accuracy')

# %% [markdown]
# ## 8. Fitting the model

# %%
history = model.fit(train_data,
                    epochs = 2,
                    validation_data = test_data,
                    batch_size = 32)
# Out:
# Epoch 1/2
# 469/469 [==============================] - 194s 387ms/step - loss: 1.4738 - accuracy: 0.5069 - val_loss: 0.9794 - val_accuracy: 0.6877
# Epoch 2/2
# 469/469 [==============================] - 182s 388ms/step - loss: 0.9762 - accuracy: 0.6823 - val_loss: 0.7092 - val_accuracy: 0.7723

# %% [markdown]
# ## 9. Checking how well your predictions are

# %%
def plot_loss_curves(history):
  loss = history.history['loss']
  val_loss = history.history['val_loss']

  accuracy = history.history['accuracy']
  val_accuracy = history.history['val_accuracy']

  epochs = range(len(history.history['loss']))

  # Plot loss
  plt.plot(epochs, loss, label='training_loss')
  plt.plot(epochs, val_loss, label='val_loss')
  plt.title('Loss')
  plt.xlabel('Epochs')
  plt.legend()

  # Plot accuracy
  plt.figure()
  plt.plot(epochs, accuracy, label='training_accuracy')
  plt.plot(epochs, val_accuracy, label='val_accuracy')
  plt.title('Accuracy')
  plt.xlabel('Epochs')
  plt.legend();

# %%
plot_loss_curves(history)

# %%
loaded_model = tf.keras.models.load_model("/content/Veggies_Classifier_CNN_model.h5")

# %% [markdown]
# ## 10. Check your model predictions

# %%
def load_and_prep_image(filename, img_shape=224, scale=True):
  # Read in the image
  img = tf.io.read_file(filename)
  # Decode it into a tensor
  img = tf.image.decode_jpeg(img)
  # Resize the image
  img = tf.image.resize(img, [img_shape, img_shape])
  if scale:
    # Rescale the image (get all values between 0 and 1)
    return img/255.
  else:
    return img

# %%
def pred_and_plot(model, filename, class_names):
  # Import the target image and preprocess it
  img = load_and_prep_image(filename)

  # Make a prediction
  pred = model.predict(tf.expand_dims(img, axis=0))

  pred_class = class_names[pred.argmax()] # if more than one output, take the max
  
  # Plot the image and predicted class
  plt.imshow(img)
  plt.title(f"Prediction: {pred_class}")
  plt.axis(False);

# %%
pred_and_plot(loaded_model, "/content/Vegetable Images/test/Bean/0005.jpg", class_names)
# Out:
# 1/1 [==============================] - 0s 19ms/step

# %% [markdown]
# ## 🎉 Congrats on Building the Model Now we just have to save this model

# %%
model.save("model.h5")
